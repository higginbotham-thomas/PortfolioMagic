# %%
from dotenv import load_dotenv
import os
import json
import plots

# %%
load_dotenv()

FMPKEY = os.getenv('FMPKEY')

json_str = os.getenv('SYM_LIST')
sym_list = json.loads(json_str)

# %%
sym_list
# Out:
# ['EOG', 'MET']

# %%
plots.plot_sma(sym_list)
